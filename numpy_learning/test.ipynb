# %%
# !pip install numpy
import numpy as np
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %% [markdown]
# ### Armethic oipertion in nummpy

# %%
list1=[1,2,3]
list2=[2,3,4]
list1+list2
# Out:
# [1, 2, 3, 2, 3, 4]

# %%
array_1=np.array([1,2,3])
array_3=np.array([2,3,4])
print(array_1 * array_3)
# Out:
# [ 2  6 12]
